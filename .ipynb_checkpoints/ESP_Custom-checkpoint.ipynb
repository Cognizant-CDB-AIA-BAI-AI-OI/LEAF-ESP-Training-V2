# %%
#All Imports

import copy
import h5py
import io
import json
import numpy as np
import os
import pandas as pd
import pickle
import time
import argparse
from collections import OrderedDict

from keras.models import load_model
from keras.models import clone_model
from google.protobuf.json_format import ParseDict

from esp_sdk.v1_0.esp_persistor import EspPersistor
from esp_sdk.v1_0.esp_service import EspService
from data_util.data_set_encoder import DataSetEncoder
from data_util.data_set_util import DataSetUtil

from getFitness import Fitness_Evaluator 

print ("ALL IMPORTS COMPLETED !!!!!!")
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# ALL IMPORTS COMPLETED !!!!!!

# %%
DATA_PATH = "./data_exe3"
print ("**********OS Current Directory********",os.getcwd())
TRAINING_DATA_CSV = "training_data_withScore.csv"
training_data = pd.read_csv(TRAINING_DATA_CSV, sep=',')
training_data.head(10)
# Out:
# **********OS Current Directory******** C:\Users\Anuja\Desktop\ESP-Training
#     Region       OS page color button color Conversion Rate  Scores
# 0  America  Windows      White          Red             Yes    0.65
# 1  America    MacOS      White          Red              No    0.00
# 2  America    Linux      White          Red              No    0.31
# 3  America  Windows      White          Red             Yes    0.65
# 4  America    MacOS      White         Blue             Yes    0.94
# 5  America    Linux      White         Blue             Yes    0.63
# 6  America  Windows      White          Red             Yes    0.65
# 7  America    MacOS      White         Blue             Yes    0.94
# 8  America    Linux      White          Red              No    0.31
# 9  America  Windows      White         Blue              No    0.17

# %%
columnsarr=list(training_data.columns.values)
CAO_variables = [2,2,1]

# %%
#File name definitions

#Context, Actions and Outcomes column names


CONTEXT_CSV = os.path.join(DATA_PATH, "context.csv")
ACTIONS_CSV = os.path.join(DATA_PATH, "actions.csv")
OUTCOMES_CSV = os.path.join(DATA_PATH, "outcomes.csv")
POSSIBLE_VALUES_CSV = os.path.join(DATA_PATH, "possible_values.csv")

# %%
#Evaluation samples: samples we want to use to evaluate a candidate

EVALUATION_SAMPLES_CSV =  os.path.join(DATA_PATH, "splits/70-30/val_set_0.csv")

# %%
PRESCRIPTOR_JSON = os.path.join(DATA_PATH, "prescriptor.json")
PRESCRIPTOR_H5 = os.path.join(DATA_PATH, 'prescriptor.h5')
PREDICTOR_H5 = os.path.join(DATA_PATH, "predictor.h5")

# %%
#Output directory to store training results

TRAINED_PRESCRIPTORS_DIR = "trained_prescriptors/"

# %%
#Context Creation

context=[]
for i in range(0,CAO_variables[0]):
    context.append(columnsarr[i])
context_df=pd.DataFrame(columns=context)
context_names = list(context_df.columns)
print ("# context variables : ", context_names)
context_df = context_df.replace(np.nan, '', regex=True)
context_df.to_csv(CONTEXT_CSV,index=False)
# Out:
# # context variables :  ['Region', 'OS']

# %%
#Action Creation

action=[]
for i in range(0,CAO_variables[1]):
    action.append(columnsarr[i+CAO_variables[0]])
actions_df=pd.DataFrame(columns=action)
actions_names = list(actions_df.columns)
print ("# Action variables : ", actions_names)
actions_df = actions_df.replace(np.nan, '', regex=True)
actions_df.to_csv(ACTIONS_CSV,index=False)
# Out:
# # Action variables :  ['page color', 'button color']

# %%
#Outcome Creation

outcome=[]
for i in range(0,CAO_variables[2]):
    outcome.append(columnsarr[i+CAO_variables[0]+CAO_variables[1]])
outcome_df=pd.DataFrame(columns=outcome)
outcome_names = list(outcome_df.columns)
print ("# Outcome  variables : ", outcome_names)
outcome_df = outcome_df.replace(np.nan, '', regex=True)
outcome_df.to_csv(OUTCOMES_CSV,index=False)
# Out:
# # Outcome  variables :  ['Conversion Rate']

# %%
#Possible Values

possible_values_list=[]
for i in range(0,sum(CAO_variables)):
    possible_values_list.append(training_data[columnsarr[i]].str.capitalize().unique().flatten())
    
possible_values_df=pd.DataFrame(data={'value':possible_values_list},index=columnsarr[0:sum(CAO_variables)]).value.apply(pd.Series).T
possible_values_df = possible_values_df.replace(np.nan, '', regex=True)
possible_values_df.to_csv(POSSIBLE_VALUES_CSV,index=False)

# %%
#Create Experiment Parameters

possible_values_dict = DataSetEncoder.get_possible_values_dict(POSSIBLE_VALUES_CSV)
experiment_params = DataSetEncoder.generate_model_description(possible_values_dict,
                                                              CONTEXT_CSV,
                                                              ACTIONS_CSV,
                                                              nb_hidden_units=10,
                                                              use_bias=True,
                                                              activation_function="tanh",
                                                              include_evo_description=True)
                                                              
                                                              
#Tweak Experiment Parameters

experiment_params["LEAF"] = {
    "esp_host": "v1.esp.evolution.ml",
    "esp_port": 50051,
    "representation": "NNWeights",
    "experiment_id":"esp-custom",
    "version": "1.0.0",
    "candidates_to_persist": "all",
    "persistence_dir": TRAINED_PRESCRIPTORS_DIR
}
experiment_params["evolution"] = {
    "nb_generations": 5,
    "population_size": 25,
    "nb_elites": 1,
    "remove_population_pct": 0.8,
    "mutation_probability": 0.5,
    "mutation_factor": 0.5,
    "initialization_distribution": "orthogonal",
    "initialization_range": 1
}

# Network

#experiment_params["network"]["nb_hidden_units"] = 25
experiment_params["network"]["activation_function"] = "tanh"

# %%
#Save Experiment Parameters

with open(PRESCRIPTOR_JSON, 'w') as fp:
    json.dump(experiment_params, fp)
    
#load Experiment Parameters
with open(PRESCRIPTOR_JSON) as json_data:
    experiment_params = json.load(json_data)
    
    
evaluator_df = training_data.drop('Conversion Rate', 1).drop_duplicates()
print ("evaluator_df  >>> ", evaluator_df)
print ("len(evaluator_df) ... ", len(evaluator_df))
# Out:
# evaluator_df  >>>        Region       OS page color button color  Scores
# 0    America  Windows      White          Red    0.65
# 1    America    MacOS      White          Red    0.00
# 2    America    Linux      White          Red    0.31
# 4    America    MacOS      White         Blue    0.94
# 5    America    Linux      White         Blue    0.63
# 9    America  Windows      White         Blue    0.17
# 11   America    Linux       Grey         Blue    0.63
# 12   America  Windows       Grey          Red    0.72
# 13   America    MacOS       Grey          Red    0.24
# 14   America    Linux       Grey          Red    0.44
# 15   America  Windows       Grey         Blue    0.20
# 16   America    MacOS       Grey         Blue    1.00
# 77   America    Linux       grey         Blue    0.63
# 81   America  Windows       grey         Blue    0.20
# 85   America    MacOS       grey          Red    0.24
# 140     Asia  Windows      White          Red    0.76
# 141     Asia    MacOS      White          Red    0.40
# 142     Asia    Linux      White          Red    0.33
# 144     Asia    MacOS      White         Blue    0.88
# 145     Asia    Linux      White         Blue    0.67
# 149     Asia  Windows      White         Blue    0.29
# 151     Asia    Linux       Grey         Blue    0.67
# 152     Asia  Windows       Grey          Red    0.67
# 153     Asia    MacOS       Grey          Red    0.29
# 154     Asia    Linux       Grey          Red    0.50
# 155     Asia  Windows       Grey         Blue    0.38
# 156     Asia    MacOS       Grey         Blue    0.89
# len(evaluator_df) ...  27

# %%
#Presciptor Training

def create_evaluator():
    evaluator = Fitness_Evaluator(context_names, actions_names, POSSIBLE_VALUES_CSV, evaluator_df, experiment_params,training_data)
    return evaluator
    
def train(experiment_params, evaluator, checkpoint_id=None):
    esp_service = EspService(experiment_params)
    persistor = EspPersistor(experiment_params, evaluator)
    experiment_id = experiment_params["LEAF"]["experiment_id"]
    timestamp = time.strftime("%Y%m%d-%H%M%S")    
    
    print("Starting training:")
    print("  experiment_id: {}".format(experiment_id))
    print("  checkpoint_id: {}".format(checkpoint_id))
    print("  timestamp: {}".format(timestamp))
    print("  experiment results dir: {}".format(persistor.get_persistence_directory()))

    # Starting point
    if checkpoint_id:
        # We're starting with a check-pointed population.
        print("Asking ESP for a check-pointed population: {}...".format(checkpoint_id))
        response = esp_service.get_previous_population(experiment_id, checkpoint_id)
        current_gen = response.generation_count
    else:
        # We're starting with the 1st generation, which is a 'seed' population because we create it from scratch
        print("Asking ESP for a seed generation...")
        response = esp_service.get_next_population(prev_response=None)
        print("Seed generation received.")
        current_gen = 1
    nb_gen = experiment_params["evolution"]["nb_generations"]
    for gen in range(current_gen, nb_gen + 1):
        print("Evaluating the following PopulationResponse for generation {}...:".format(gen))
        esp_service.print_population_response(response)

        # Evaluate the population. This is going to update the metrics on the candidates contained in the response
        evaluator.evaluate_population(response)
        print("Evaluation done.")

        # Persist the evaluated population
        persistor.persist_response(response)
        print("Generation's info persisted to {}".format(persistor.get_persistence_directory()))

        # Print the candidates and their scores
        esp_service.print_candidates(response)
        
        print("Done with generation {}.".format(gen))
        print("--------\n")
        if gen < nb_gen:
            # Get a new generation from the previous one we've just evaluated
            print("Asking ESP for generation {}...:".format(gen + 1))
            response = esp_service.get_next_population(prev_response=response)
    return persistor.get_persistence_directory()

# %%
evaluator = create_evaluator()
experiment_results_dir = train(experiment_params, evaluator)
# Out:
# ESP service: v1.esp.evolution.ml:50051
# gRPC options:
#   grpc.max_send_message_length: 52428800
#   grpc.max_receive_message_length: 52428800
# Ready to connect.
# Requesting base model...
# Sending NextPopulation request
# NextPopulation response received.
# c:\users\anuja\anaconda3\lib\site-packages\keras\models.py:282: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Based model received.
# ESP service: v1.esp.evolution.ml:50051
# gRPC options:
#   grpc.max_send_message_length: 52428800
#   grpc.max_receive_message_length: 52428800
# Ready to connect.
# Starting training:
#   experiment_id: esp-custom
#   checkpoint_id: None
#   timestamp: 20190830-165212
#   experiment results dir: trained_prescriptors/esp-custom\1.0.0_20190830-165212
# Asking ESP for a seed generation...
# Sending NextPopulation request
# NextPopulation response received.
# Seed generation received.
# Evaluating the following PopulationResponse for generation 1...:
# PopulationResponse:
#   Generation: 1
#   Population size: 25
#   Checkpoint id: esp-custom/1/20190830-1122
#   Evaluation stats:
# ************Fitness Score:********** 12.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 17.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 19.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 12.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 19.0
# ************Fitness Score:********** 13.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 11.0
# Evaluation done.
# Generation's info persisted to trained_prescriptors/esp-custom\1.0.0_20190830-165212
# Evaluated candidates:
# Id: 1_2 Identity: (none) Metrics: {'score': 11.0}
# Id: 1_3 Identity: (none) Metrics: {'score': 11.0}
# Id: 1_17 Identity: (none) Metrics: {'score': 11.0}
# Id: 1_23 Identity: (none) Metrics: {'score': 11.0}
# Id: 1_25 Identity: (none) Metrics: {'score': 11.0}
# Id: 1_1 Identity: (none) Metrics: {'score': 12.0}
# Id: 1_12 Identity: (none) Metrics: {'score': 12.0}
# Id: 1_20 Identity: (none) Metrics: {'score': 13.0}
# Id: 1_14 Identity: (none) Metrics: {'score': 14.0}
# Id: 1_15 Identity: (none) Metrics: {'score': 14.0}
# Id: 1_22 Identity: (none) Metrics: {'score': 14.0}
# Id: 1_6 Identity: (none) Metrics: {'score': 16.0}
# Id: 1_21 Identity: (none) Metrics: {'score': 16.0}
# Id: 1_7 Identity: (none) Metrics: {'score': 17.0}
# Id: 1_8 Identity: (none) Metrics: {'score': 18.0}
# Id: 1_16 Identity: (none) Metrics: {'score': 18.0}
# Id: 1_18 Identity: (none) Metrics: {'score': 18.0}
# Id: 1_24 Identity: (none) Metrics: {'score': 18.0}
# Id: 1_9 Identity: (none) Metrics: {'score': 19.0}
# Id: 1_19 Identity: (none) Metrics: {'score': 19.0}
# Id: 1_4 Identity: (none) Metrics: {'score': 21.0}
# Id: 1_5 Identity: (none) Metrics: {'score': 21.0}
# Id: 1_10 Identity: (none) Metrics: {'score': 21.0}
# Id: 1_11 Identity: (none) Metrics: {'score': 21.0}
# Id: 1_13 Identity: (none) Metrics: {'score': 21.0}
#
# Done with generation 1.
# --------
#
# Asking ESP for generation 2...:
# Sending NextPopulation request
# NextPopulation response received.
# Evaluating the following PopulationResponse for generation 2...:
# PopulationResponse:
#   Generation: 2
#   Population size: 25
#   Checkpoint id: esp-custom/2/20190830-1122
#   Evaluation stats:
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 19.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 20.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 19.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 11.0
# Evaluation done.
# Generation's info persisted to trained_prescriptors/esp-custom\1.0.0_20190830-165212
# Evaluated candidates:
# Id: 2_4 Identity: 1_13~CUW~1_10#MGNP Metrics: {'score': 11.0}
# Id: 2_23 Identity: 1_5~CUW~1_13#MGNP Metrics: {'score': 11.0}
# Id: 2_24 Identity: 1_5~CUW~1_10#MUR Metrics: {'score': 11.0}
# Id: 2_25 Identity: 1_13~CUW~1_11#MGNP Metrics: {'score': 11.0}
# Id: 2_5 Identity: 1_4~CUW~1_10#MUR Metrics: {'score': 14.0}
# Id: 2_6 Identity: 1_11~CUW~1_5#MGNP Metrics: {'score': 14.0}
# Id: 2_10 Identity: 1_5~CUW~1_4#MUR Metrics: {'score': 14.0}
# Id: 2_3 Identity: 1_11~CUW~1_5#MGNF Metrics: {'score': 16.0}
# Id: 2_9 Identity: 1_13~CUW~1_4#MGNP Metrics: {'score': 16.0}
# Id: 2_13 Identity: 1_4~CUW~1_11#MGNF Metrics: {'score': 16.0}
# Id: 2_14 Identity: 1_10~CUW~1_11#MUR Metrics: {'score': 16.0}
# Id: 2_7 Identity: 1_5~CUW~1_4#MUR Metrics: {'score': 18.0}
# Id: 2_2 Identity: 1_5~CUW~1_10#MGNF Metrics: {'score': 19.0}
# Id: 2_12 Identity: 1_5~CUW~1_10#MGNP Metrics: {'score': 19.0}
# Id: 2_8 Identity: 1_13~CUW~1_11#MUR Metrics: {'score': 20.0}
# Id: 1_4 Identity: (none) Metrics: {'score': 21.0}
# Id: 2_11 Identity: 1_4~CUW~1_13 Metrics: {'score': 21.0}
# Id: 2_15 Identity: 1_11~CUW~1_13 Metrics: {'score': 21.0}
# Id: 2_16 Identity: 1_10~CUW~1_4 Metrics: {'score': 21.0}
# Id: 2_17 Identity: 1_5~CUW~1_4#MUR Metrics: {'score': 21.0}
# Id: 2_18 Identity: 1_4~CUW~1_10#MGNF Metrics: {'score': 21.0}
# Id: 2_19 Identity: 1_4~CUW~1_11#MGNP Metrics: {'score': 21.0}
# Id: 2_20 Identity: 1_13~CUW~1_10 Metrics: {'score': 21.0}
# Id: 2_21 Identity: 1_4~CUW~1_10#MGNP Metrics: {'score': 21.0}
# Id: 2_22 Identity: 1_13~CUW~1_4#MUR Metrics: {'score': 21.0}
#
# Done with generation 2.
# --------
#
# Asking ESP for generation 3...:
# Sending NextPopulation request
# NextPopulation response received.
# Evaluating the following PopulationResponse for generation 3...:
# PopulationResponse:
#   Generation: 3
#   Population size: 25
#   Checkpoint id: esp-custom/3/20190830-1122
#   Evaluation stats:
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 13.0
# ************Fitness Score:********** 15.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 19.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 19.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 15.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 16.0
# Evaluation done.
# Generation's info persisted to trained_prescriptors/esp-custom\1.0.0_20190830-165212
# Evaluated candidates:
# Id: 3_24 Identity: 1_4~CUW~2_11#MGNF Metrics: {'score': 11.0}
# Id: 3_4 Identity: 2_11~CUW~2_17#MUR Metrics: {'score': 13.0}
# Id: 3_8 Identity: 2_16~CUW~2_11 Metrics: {'score': 14.0}
# Id: 3_14 Identity: 2_16~CUW~2_11#MUR Metrics: {'score': 14.0}
# Id: 3_5 Identity: 2_17~CUW~2_15#MGNF Metrics: {'score': 15.0}
# Id: 3_22 Identity: 1_4~CUW~2_16#MGNF Metrics: {'score': 15.0}
# Id: 3_2 Identity: 2_17~CUW~2_15 Metrics: {'score': 16.0}
# Id: 3_3 Identity: 2_17~CUW~2_16#MGNF Metrics: {'score': 16.0}
# Id: 3_7 Identity: 2_16~CUW~2_15 Metrics: {'score': 16.0}
# Id: 3_10 Identity: 2_15~CUW~2_17#MGNP Metrics: {'score': 16.0}
# Id: 3_11 Identity: 2_17~CUW~1_4#MUR Metrics: {'score': 16.0}
# Id: 3_15 Identity: 2_11~CUW~2_17#MGNP Metrics: {'score': 16.0}
# Id: 3_19 Identity: 1_4~CUW~2_17#MGNP Metrics: {'score': 16.0}
# Id: 3_20 Identity: 2_15~CUW~1_4 Metrics: {'score': 16.0}
# Id: 3_21 Identity: 2_17~CUW~2_15#MGNF Metrics: {'score': 16.0}
# Id: 3_25 Identity: 2_17~CUW~1_4#MGNF Metrics: {'score': 16.0}
# Id: 3_16 Identity: 2_15~CUW~2_17#MGNP Metrics: {'score': 18.0}
# Id: 3_12 Identity: 2_16~CUW~2_17 Metrics: {'score': 19.0}
# Id: 3_17 Identity: 2_16~CUW~1_4#MGNF Metrics: {'score': 19.0}
# Id: 1_4 Identity: (none) Metrics: {'score': 21.0}
# Id: 3_6 Identity: 2_17~CUW~2_16#MGNP Metrics: {'score': 21.0}
# Id: 3_9 Identity: 2_15~CUW~1_4#MGNP Metrics: {'score': 21.0}
# Id: 3_13 Identity: 2_15~CUW~2_11#MGNF Metrics: {'score': 21.0}
# Id: 3_18 Identity: 2_15~CUW~2_16#MGNP Metrics: {'score': 21.0}
# Id: 3_23 Identity: 2_11~CUW~1_4#MGNP Metrics: {'score': 21.0}
#
# Done with generation 3.
# --------
#
# Asking ESP for generation 4...:
# Sending NextPopulation request
# NextPopulation response received.
# Evaluating the following PopulationResponse for generation 4...:
# PopulationResponse:
#   Generation: 4
#   Population size: 25
#   Checkpoint id: esp-custom/4/20190830-1122
#   Evaluation stats:
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 17.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 15.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 14.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 11.0
# ************Fitness Score:********** 21.0
# Evaluation done.
# Generation's info persisted to trained_prescriptors/esp-custom\1.0.0_20190830-165212
# Evaluated candidates:
# Id: 4_24 Identity: 1_4~CUW~3_13#MUR Metrics: {'score': 11.0}
# Id: 4_16 Identity: 3_9~CUW~3_6 Metrics: {'score': 14.0}
# Id: 4_19 Identity: 3_6~CUW~3_9#MUR Metrics: {'score': 14.0}
# Id: 4_6 Identity: 1_4~CUW~3_9#MGNF Metrics: {'score': 15.0}
# Id: 4_10 Identity: 1_4~CUW~3_18#MGNP Metrics: {'score': 16.0}
# Id: 4_18 Identity: 3_13~CUW~3_18#MGNF Metrics: {'score': 16.0}
# Id: 4_4 Identity: 1_4~CUW~3_6#MGNP Metrics: {'score': 17.0}
# Id: 4_8 Identity: 1_4~CUW~3_18#MUR Metrics: {'score': 18.0}
# Id: 1_4 Identity: (none) Metrics: {'score': 21.0}
# Id: 4_2 Identity: 3_18~CUW~1_4 Metrics: {'score': 21.0}
# Id: 4_3 Identity: 3_18~CUW~3_13#MGNF Metrics: {'score': 21.0}
# Id: 4_5 Identity: 3_18~CUW~1_4#MUR Metrics: {'score': 21.0}
# Id: 4_7 Identity: 3_18~CUW~3_6#MGNF Metrics: {'score': 21.0}
# Id: 4_9 Identity: 3_13~CUW~3_6#MUR Metrics: {'score': 21.0}
# Id: 4_11 Identity: 3_6~CUW~3_9#MUR Metrics: {'score': 21.0}
# Id: 4_12 Identity: 3_6~CUW~3_18#MGNF Metrics: {'score': 21.0}
# Id: 4_13 Identity: 3_18~CUW~3_6#MUR Metrics: {'score': 21.0}
# Id: 4_14 Identity: 3_13~CUW~3_9#MGNP Metrics: {'score': 21.0}
# Id: 4_15 Identity: 3_6~CUW~1_4#MUR Metrics: {'score': 21.0}
# Id: 4_17 Identity: 1_4~CUW~3_9#MGNP Metrics: {'score': 21.0}
# Id: 4_20 Identity: 3_13~CUW~3_18#MGNP Metrics: {'score': 21.0}
# Id: 4_21 Identity: 1_4~CUW~3_18#MUR Metrics: {'score': 21.0}
# Id: 4_22 Identity: 1_4~CUW~3_9#MGNF Metrics: {'score': 21.0}
# Id: 4_23 Identity: 3_18~CUW~3_13#MGNF Metrics: {'score': 21.0}
# Id: 4_25 Identity: 3_9~CUW~3_18#MGNP Metrics: {'score': 21.0}
#
# Done with generation 4.
# --------
#
# Asking ESP for generation 5...:
# Sending NextPopulation request
# NextPopulation response received.
# Evaluating the following PopulationResponse for generation 5...:
# PopulationResponse:
#   Generation: 5
#   Population size: 25
#   Checkpoint id: esp-custom/5/20190830-1122
#   Evaluation stats:
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 12.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 16.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 18.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 12.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# ************Fitness Score:********** 21.0
# Evaluation done.
# Generation's info persisted to trained_prescriptors/esp-custom\1.0.0_20190830-165212
# Evaluated candidates:
# Id: 5_4 Identity: 4_7~CUW~4_2#MGNF Metrics: {'score': 12.0}
# Id: 5_14 Identity: 4_3~CUW~1_4#MUR Metrics: {'score': 12.0}
# Id: 5_2 Identity: 4_7~CUW~1_4#MGNP Metrics: {'score': 16.0}
# Id: 5_5 Identity: 4_3~CUW~4_5#MUR Metrics: {'score': 16.0}
# Id: 5_9 Identity: 1_4~CUW~4_3#MGNP Metrics: {'score': 16.0}
# Id: 5_12 Identity: 4_5~CUW~4_7#MUR Metrics: {'score': 18.0}
# Id: 1_4 Identity: (none) Metrics: {'score': 21.0}
# Id: 5_3 Identity: 4_3~CUW~4_2 Metrics: {'score': 21.0}
# Id: 5_6 Identity: 4_2~CUW~4_7#MGNF Metrics: {'score': 21.0}
# Id: 5_7 Identity: 4_3~CUW~1_4 Metrics: {'score': 21.0}
# Id: 5_8 Identity: 4_3~CUW~4_2#MGNP Metrics: {'score': 21.0}
# Id: 5_10 Identity: 1_4~CUW~4_2#MGNP Metrics: {'score': 21.0}
# Id: 5_11 Identity: 4_5~CUW~4_7#MGNF Metrics: {'score': 21.0}
# Id: 5_13 Identity: 4_7~CUW~4_5 Metrics: {'score': 21.0}
# Id: 5_15 Identity: 4_7~CUW~1_4#MGNP Metrics: {'score': 21.0}
# Id: 5_16 Identity: 1_4~CUW~4_5#MGNF Metrics: {'score': 21.0}
# Id: 5_17 Identity: 1_4~CUW~4_2 Metrics: {'score': 21.0}
# Id: 5_18 Identity: 4_2~CUW~1_4#MGNF Metrics: {'score': 21.0}
# Id: 5_19 Identity: 4_2~CUW~4_5#MGNF Metrics: {'score': 21.0}
# Id: 5_20 Identity: 4_7~CUW~4_3 Metrics: {'score': 21.0}
# Id: 5_21 Identity: 4_2~CUW~1_4#MGNF Metrics: {'score': 21.0}
# Id: 5_22 Identity: 4_7~CUW~4_5#MGNP Metrics: {'score': 21.0}
# Id: 5_23 Identity: 4_2~CUW~4_7#MGNF Metrics: {'score': 21.0}
# Id: 5_24 Identity: 4_3~CUW~4_5 Metrics: {'score': 21.0}
# Id: 5_25 Identity: 4_3~CUW~4_7 Metrics: {'score': 21.0}
#
# Done with generation 5.
# --------

# %%
#Evolution Summary

stats_file = os.path.join(experiment_results_dir, 'experiment_stats.csv')
with open(stats_file) as csv_file:
    stats_df = pd.read_csv(csv_file, sep=',')
stats_df
# Out:
#    generation               checkpoint_id  max_score  min_score  mean_score  \
# 0           1  esp-custom/1/20190830-1122       21.0       11.0       15.92
# 1           2  esp-custom/2/20190830-1122       21.0       11.0       17.44
# 2           3  esp-custom/3/20190830-1122       21.0       11.0       16.96
# 3           4  esp-custom/4/20190830-1122       21.0       11.0       19.12
# 4           5  esp-custom/5/20190830-1122       21.0       12.0       19.56
#
#   cid_min_score cid_max_score
# 0           1_2          1_13
# 1           2_4          2_22
# 2          3_24          3_23
# 3          4_24          4_25
# 4           5_4          5_25

# %%
#Evolution Plot

from IPython.display import Image
plot_file = os.path.join(experiment_results_dir, 'experiment_stats.png')
Image(filename=plot_file)

# %%
#Load Best Candidate

last_generation = experiment_params["evolution"]["nb_generations"]
candidate_id_with_max_score = stats_df.iloc[experiment_params["evolution"]["nb_generations"] -1]["cid_max_score"]
max_score = stats_df.iloc[last_generation -1]["max_score"]
print('Best candidate is ',candidate_id_with_max_score,' with a score of ',max_score)
# Out:
# Best candidate is  5_25  with a score of  21.0

# %%
#Prescribe the actions based on the contexts from the saved model

best_model_filename = os.path.join(experiment_results_dir,
                                   str(last_generation),
                                   candidate_id_with_max_score + ".h5")
best_model = load_model(best_model_filename)
best_model.summary()

windows_user = np.array([[1, 0, 0]])
region = np.array([[1, 0]])

prescription = best_model.predict([region,windows_user])
print("The raw Prescriptor model output is {}".format(prescription))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Region_input (InputLayer)       (None, 2)            0
# __________________________________________________________________________________________________
# OS_input (InputLayer)           (None, 3)            0
# __________________________________________________________________________________________________
# Region (Dense)                  (None, 10)           30          Region_input[0][0]
# __________________________________________________________________________________________________
# OS (Dense)                      (None, 10)           40          OS_input[0][0]
# __________________________________________________________________________________________________
# add_20518 (Add)                 (None, 10)           0           Region[0][0]
#                                                                  OS[0][0]
# __________________________________________________________________________________________________
# first_hidden_activation (Activa (None, 10)           0           add_20518[0][0]
# __________________________________________________________________________________________________
# page color (Dense)              (None, 2)            22          first_hidden_activation[0][0]
# __________________________________________________________________________________________________
# button color (Dense)            (None, 2)            22          first_hidden_activation[0][0]
# __________________________________________________________________________________________________
# lambda_61319 (Lambda)           (None, 2)            0           page color[0][0]
# __________________________________________________________________________________________________
# lambda_61320 (Lambda)           (None, 2)            0           button color[0][0]
# ==================================================================================================
# Total params: 114
# Trainable params: 114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# The raw Prescriptor model output is [array([[0., 1.]], dtype=float32), array([[0., 1.]], dtype=float32)]
